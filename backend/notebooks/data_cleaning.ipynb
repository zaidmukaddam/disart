# %% [markdown]
# # Data cleaning for museum objects
#
# We only want certain kinds of items from the Harvard Art Museums that fit well with our application. For example, the Art Museums seem to have a large collection of images of coins, and those don't really fit well with CLIP, so we filter them out in this step.
#
# Other objects have no images, which make them not useful. Let's explore what these images look like!

# %%
# %pip install inline-sql
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# Collecting inline-sql
#   Using cached inline_sql-0.1.0-py3-none-any.whl (5.1 kB)
# Collecting duckdb~=0.5.1
#   Using cached duckdb-0.5.1-cp38-cp38-win_amd64.whl (11.6 MB)
# Collecting pandas~=1.3.5
#   Using cached pandas-1.3.5-cp38-cp38-win_amd64.whl (10.2 MB)
# Collecting sqlparse~=0.4.3
#   Using cached sqlparse-0.4.3-py3-none-any.whl (42 kB)
# Requirement already satisfied: numpy>=1.14 in d:\developer_zaid\disart\backend\env\lib\site-packages (from duckdb~=0.5.1->inline-sql) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in d:\developer_zaid\disart\backend\env\lib\site-packages (from pandas~=1.3.5->inline-sql) (2.8.2)
# Collecting pytz>=2017.3
#   Using cached pytz-2022.6-py2.py3-none-any.whl (498 kB)
# Requirement already satisfied: six>=1.5 in d:\developer_zaid\disart\backend\env\lib\site-packages (from python-dateutil>=2.7.3->pandas~=1.3.5->inline-sql) (1.16.0)
# Installing collected packages: duckdb, pytz, pandas, sqlparse, inline-sql
# Successfully installed duckdb-0.5.1 inline-sql-0.1.0 pandas-1.3.5 pytz-2022.6 sqlparse-0.4.3
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 22.3.1 is available.
# You should consider upgrading via the 'd:\Developer_Zaid\disart\backend\env\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import json

with open("../data/artmuseums.json", "r") as f:
    dataset = json.load(f)

# %%
len(dataset)
# Out:
# 231500

# %%
dataset[0]
# Out:
# {'copyright': None,
#  'contextualtextcount': 0,
#  'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Loan from the Trustees of the Arthur Stone Dewing Greek Numismatic Foundation',
#  'accesslevel': 1,
#  'dateoflastpageview': '2020-11-25',
#  'classificationid': 50,
#  'division': 'Asian and Mediterranean Art',
#  'markscount': 0,
#  'publicationcount': 0,
#  'totaluniquepageviews': 7,
#  'contact': 'am_asianmediterranean@harvard.edu',
#  'colorcount': 4,
#  'rank': 1003,
#  'details': {'coins': {'reverseinscription': None,
#    'dieaxis': '8',
#    'metal': 'AR',
#    'obverseinscription': None,
#    'denomination': 'litra',
#    'dateonobject': None}},
#  'state': None,
#  'id': 189263,
#  'verificationleveldescription': 'Good. Object is well described and information is vetted',
#  'period': 'Classical period, Early',
#  'images': [{'date': '2004-06-03',
#    'copyright': 'President and Fellows of Harvard College',
#    'imageid': 38027,
#    'idsid': 18778012,
#    'format': 'image/jpeg',
#    'description': None,
#    'technique': None,
#    'renditionnumber': 'COIN00538',
#    'displayorder': 1,
#    'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN00538_dynmc',
#    'alttext': None,
#    'width': 1024,
#    'publiccaption': None,
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18778012',
#    'height': 478}],
#  'worktypes': [{'worktypeid': '103', 'worktype': 'coin'}],
#  'imagecount': 1,
#  'totalpageviews': 7,
#  'accessionyear': None,
#  'standardreferencenumber': None,
#  'signed': None,
#  'classification': 'Coins',
#  'relatedcount': 0,
#  'verificationlevel': 3,
#  'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN00538_dynmc',
#  'titlescount': 1,
#  'peoplecount': 0,
#  'style': None,
#  'lastupdate': '2022-11-30T05:35:30-0500',
#  'commentary': None,
#  'periodid': 906,
#  'technique': 'Struck',
#  'edition': None,
#  'description': "Obv.: Lion's head facing; Rev.: RECI in laurel wreath",
#  'medium': 'Silver',
#  'lendingpermissionlevel': 0,
#  'title': 'Litra of Rhegion',
#  'accessionmethod': None,
#  'colors': [{'color': '#000000',
#    'spectrum': '#1eb264',
#    'hue': 'Black',
#    'percent': 0.9365714285714286,
#    'css3': '#000000'},
#   {'color': '#4b3232',
#    'spectrum': '#4ab851',
#    'hue': 'Red',
#    'percent': 0.06190476190476191,
#    'css3': '#2f4f4f'},
#   {'color': '#190000',
#    'spectrum': '#2eb45d',
#    'hue': 'Black',
#    'percent': 0.0008571428571428571,
#    'css3': '#000000'},
#   {'color': '#000019',
#    'spectrum': '#1eb264',
#    'hue': 'Black',
#    'percent': 0.0006666666666666666,
#    'css3': '#000000'}],
#  'provenance': 'Acq. Ravel, 1929',
#  'groupcount': 0,
#  'dated': 'c. 450 BCE',
#  'department': 'Department of Ancient and Byzantine Art & Numismatics',
#  'dateend': -445,
#  'url': 'https://www.harvardartmuseums.org/collections/object/189263',
#  'dateoffirstpageview': '2014-10-17',
#  'century': '5th century BCE',
#  'objectnumber': '1.1965.534',
#  'labeltext': None,
#  'datebegin': -455,
#  'culture': 'Greek',
#  'exhibitioncount': 0,
#  'imagepermissionlevel': 0,
#  'mediacount': 0,
#  'objectid': 189263,
#  'techniqueid': 7320,
#  'dimensions': '0.71 g',
#  'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/189263',
#    'type': 'IIIF Manifest',
#    'format': 'application/json',
#    'profile': 'http://iiif.io/api/presentation/2/context.json'}]}

# %%
sum(["primaryimageurl" not in item for item in dataset])
# Out:
# 22679

# %%
len(set([item["primaryimageurl"] for item in dataset if "primaryimageurl" in item]))
# Out:
# 206451

# %%
210681 + 22994
# Out:
# 233675

# %%
len(dataset)
# Out:
# 231500

# %% [markdown]
# Okay, it looks like about 10% of the items in the dataset don't have any image associated with them. Furthermore, there are 3000 image URLs that are duplicated. Let's look at some of these duplicates.

# %%
from collections import Counter

Counter([item["primaryimageurl"] for item in dataset if "primaryimageurl" in item]).most_common(40)
# Out:
# [('https://nrs.harvard.edu/urn-3:HUAM:INV180154_dynmc', 48),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180030_dynmc', 38),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180019_dynmc', 36),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180031_dynmc', 34),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180197_dynmc', 32),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180165_dynmc', 28),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180032_dynmc', 27),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV186007_dynmc', 26),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180113_dynmc', 25),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180100_dynmc', 25),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180157_dynmc', 23),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV179871_dynmc', 23),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180153_dynmc', 23),
#  ('https://nrs.harvard.edu/urn-3:HUAM:VRS35829_dynmc', 22),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV141481_dynmc', 22),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180155_dynmc', 22),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180241_dynmc', 22),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV186005_dynmc', 21),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV185977_dynmc', 21),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180107_dynmc', 20),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV186185_dynmc', 20),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180028_dynmc', 20),
#  ('https://nrs.harvard.edu/urn-3:HUAM:767370', 19),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180027_dynmc', 19),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV186193_dynmc', 17),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180068_dynmc', 17),
#  ('https://nrs.harvard.edu/urn-3:HUAM:CARP12130_dynmc', 16),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180029_dynmc', 16),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV185670_dynmc', 16),
#  ('https://nrs.harvard.edu/urn-3:HUAM:VRS33642_dynmc', 15),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV140426_dynmc', 15),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV186180_dynmc', 14),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180112_dynmc', 14),
#  ('https://nrs.harvard.edu/urn-3:HUAM:VRS31249_dynmc', 12),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV179869_dynmc', 12),
#  ('https://nrs.harvard.edu/urn-3:HUAM:CARP12081_dynmc', 11),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV179867_dynmc', 11),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180000_dynmc', 10),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV203770_dynmc', 10),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV203772_dynmc', 10)]

# %% [markdown]
# Okay, looks like all of the coins have dimensions in grams. The weird print also has a `None` dimension. Maybe for now I'll just filter for all items that have an image and some 2D dimensions.

# %%
import random

random.seed(42)

shuffled_dataset = list(dataset)
random.shuffle(shuffled_dataset)

[item["dimensions"] for item in shuffled_dataset[:100]]
# Out:
# ['image: 9.5 x 12 cm (3 3/4 x 4 3/4 in.)',
#  'image: 12.7 x 10.16 cm (5 x 4 in.)',
#  '10.16 x 12.7 cm (4 x 5 in.)',
#  '16.3 x 8.2 x 1.2 cm (6 7/16 x 3 1/4 x 1/2 in.)',
#  None,
#  'vertical ōban: H. 36.8 × W. 25.4 cm (14 1/2 × 10 in.)',
#  'plate: 26.7 x 44.6 cm (10 1/2 x 17 9/16 in.)',
#  'sheet: 111.3 x 88.6 cm (43 13/16 x 34 7/8 in.)',
#  '24.13 x 15.24 cm (9 1/2 x 6 in.)',
#  None,
#  '98.5 x 55 x 3.5 cm (38 3/4 x 21 5/8 x 1 3/8 in.)',
#  '10.3 x 11.1 cm (4 1/16 x 4 3/8 in.)',
#  '8.46 g',
#  '21.5 x 28 cm (8 7/16 x 11 in.)',
#  '6 x 19 cm (2 3/8 x 7 1/2 in.)',
#  '3.03 g',
#  'plate: 28.9 x 45.6 cm (11 3/8 x 17 15/16 in.)',
#  '60.5 x 49.5 cm (23 13/16 x 19 1/2 in.)',
#  '36.2 x 132.72 cm (14 1/4 x 52 1/4 in.)',
#  'image: 17.5 x 24.2 cm (6 7/8 x 9 1/2 in.)',
#  '2.4 x 3.6 cm (15/16 x 1 7/16 in.)',
#  'image: 20.7 x 15.8 cm (8 1/8 x 6 1/4 in.)',
#  '2.5 x 3.5 cm (1 x 1 3/8 in.)',
#  'image: 18.1 x 23.9 cm (7 1/8 x 9 7/16 in.)\r\nsheet: 18.8 x 25.2 cm (7 3/8 x 9 15/16 in.)',
#  '10.16 x 12.7 cm (4 x 5 in.)',
#  '4.36 g',
#  None,
#  None,
#  '22.9 x 28.2 cm (9 x 11 1/8 in.)',
#  'image: 35 x 49.3 cm (13 3/4 x 19 7/16 in.)\r\nsheet: 49.5 x 65 cm (19 1/2 x 25 9/16 in.)',
#  '3.93 g',
#  '8.33 g',
#  'sheet: 92 x 62.5 cm (36 1/4 x 24 5/8 in.)',
#  '4.5 x 5.9 cm (1 3/4 x 2 5/16 in.)',
#  None,
#  'sheet: 39.6 × 56.4 cm (15 9/16 × 22 3/16 in.)\r\nimage: 38.3 × 55.6 cm (15 1/16 × 21 7/8 in.)',
#  'image: 15.6 x 8.4 cm (6 1/8 x 3 5/16 in.)',
#  'plate: 23.8 x 18.6 cm (9 3/8 x 7 5/16 in.)',
#  'image: 20.4 x 30.6 cm (8 1/16 x 12 1/16 in.)',
#  None,
#  '2.3 x 2 x 2.4 cm (7/8 x 13/16 x 15/16 in.)',
#  '63 x 30.5 x 18 cm (24 13/16 x 12 x 7 1/16 in.)',
#  '38.9 x 56.3 cm (15 5/16 x 22 3/16 in.)',
#  'sheet: 52.3 x 64.9 cm (20 9/16 x 25 9/16 in.)',
#  None,
#  None,
#  '29.8 x 37.8 cm (11 3/4 x 14 7/8 in.)',
#  None,
#  'image: 28 x 37.8 cm (11 x 14 7/8 in.)\r\nsheet: 29.9 x 39.8 cm (11 3/4 x 15 11/16 in.)',
#  '5.9 x 4.5 cm (2 5/16 x 1 3/4 in.)',
#  '8.92 g',
#  '21.7 x 41.2 cm (8 9/16 x 16 1/4 in.)',
#  None,
#  'design: 24.1 x 21.8 cm (9 1/2 x 8 9/16 in.)',
#  None,
#  'image: 2.4 x 3.6 cm (15/16 x 1 7/16 in.)\r\nsheet: 3.4 x 11.7 cm (1 5/16 x 4 5/8 in.)',
#  '2.2 x 8.1 cm (7/8 x 3 3/16 in.)',
#  None,
#  'image: 10.16 x 12.7 cm (4 x 5 in.)',
#  '17.8 g',
#  'image: 19.2 x 24 cm (7 9/16 x 9 7/16 in.)',
#  'sheet: 70.2 x 52.5 cm (27 5/8 x 20 11/16 in.)',
#  'image: 18.1 x 24.6 cm (7 1/8 x 9 11/16 in.)',
#  None,
#  'image: 8.8 x 12.5 cm (3 7/16 x 4 15/16 in.)',
#  'plate: 15.9 x 10.5 cm (6 1/4 x 4 1/8 in.)',
#  'actual: 51 x 38.1 cm (20 1/16 x 15 in.)',
#  'sheet: 37.5 x 57.8 cm (14 3/4 x 22 3/4 in.)',
#  '5.81 g',
#  '17.9 x 23.3 cm (7 1/16 x 9 3/16 in.)',
#  'sheet: 100.2 x 63.3 cm (39 7/16 x 24 15/16 in.)',
#  'film size: 14 x 17',
#  'image: 16.4 x 23.8 cm (6 7/16 x 9 3/8 in.)',
#  None,
#  None,
#  '2.75 cm (1 1/16 in.)',
#  'Diam. 22.6 cm (8 7/8 in.)',
#  None,
#  'design: 27 x 20.2 cm (10 5/8 x 7 15/16 in.)',
#  None,
#  'mount: 70.2 x 55.2 cm (27 5/8 x 21 3/4 in.)',
#  '9.5 x 17.2 cm (3.74 x 6.77 in)',
#  '34.29 x 7.62 cm (13 1/2 x 3 in.)',
#  None,
#  '2.4 x 3.6 cm (15/16 x 1 7/16 in.)',
#  'actual: 39.5 x 58.5 cm (15 9/16 x 23 1/16 in.)',
#  None,
#  '3 x 3.5 cm (1 3/16 x 1 3/8 in.)',
#  '38.7 x 23.2 cm (15 1/4 x 9 1/8 in.)',
#  '49.5 x 63.5 cm (19 1/2 x 25 in.)',
#  '6 x 4 cm (2 3/8 x 1 9/16 in.)',
#  'mount: 71 x 55.7 cm (27 15/16 x 21 15/16 in.)',
#  '7.17 g',
#  '16.3 x 14.3 cm (6 7/16 x 5 5/8 in.)',
#  'H. 6.5  W. 9.4  Th. 0.5-0.9',
#  None,
#  'mount: 35.5 x 56 cm (14 x 22 1/16 in.)',
#  '3.49 x 10.8 x 7.94 cm (1 3/8 x 4 1/4 x 3 1/8 in.)',
#  '3 x 3.5 cm (1 3/16 x 1 3/8 in.)',
#  '15.24 x 24.13 x 10.8 cm (6 x 9 1/2 x 4 1/4 in.)\r\n527 g']

# %%
import re

DIMS_RE = re.compile(r"([0-9]+\.?[0-9]*) ?x ?(?:W\.)? ?([0-9]+\.?[0-9]*) ?(?:x [0-9.]+)? ?cm", re.IGNORECASE)

# %%
[
    DIMS_RE.search(text) for text in (
        "2.89 g",
        "2.89 x 45.7 cm",
        "11.5 x 14.3 cm (4 1/2 x 5 5/8 in.)",
        "paper: H. 47.8 x W. 48.5 cm (18 13/16 x 19 1/8 in.)",
    )
]
# Out:
# [None,
#  <re.Match object; span=(0, 14), match='2.89 x 45.7 cm'>,
#  <re.Match object; span=(0, 14), match='11.5 x 14.3 cm'>,
#  <re.Match object; span=(10, 27), match='47.8 x W. 48.5 cm'>]

# %%
dataset2 = []

for item in dataset:
    if item["dimensions"]:
        if matches := DIMS_RE.search(item["dimensions"]):
            height, width = float(matches.group(1)), float(matches.group(2))
            dataset2.append({**item, "dimheight": height, "dimwidth": width})

print(f"dataset2 has {len(dataset2)} items")
# Out:
# dataset2 has 137279 items

# %%
dataset2[0]
# Out:
# {'copyright': None,
#  'contextualtextcount': 0,
#  'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Anonymous Loan in honor of Israel Goldman',
#  'accesslevel': 1,
#  'dateoflastpageview': '2022-10-02',
#  'classificationid': 23,
#  'division': 'Asian and Mediterranean Art',
#  'markscount': 0,
#  'publicationcount': 0,
#  'totaluniquepageviews': 75,
#  'contact': 'am_asianmediterranean@harvard.edu',
#  'colorcount': 10,
#  'rank': 3412,
#  'state': None,
#  'id': 211700,
#  'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#  'period': 'Edo period, 1615-1868',
#  'images': [{'date': '2005-09-19',
#    'copyright': 'President and Fellows of Harvard College',
#    'imageid': 61812,
#    'idsid': 18782938,
#    'format': 'image/jpeg',
#    'description': None,
#    'technique': None,
#    'renditionnumber': 'INV017540',
#    'displayorder': 1,
#    'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV017540_dynmc',
#    'alttext': None,
#    'width': 712,
#    'publiccaption': None,
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18782938',
#    'height': 1024}],
#  'worktypes': [{'worktypeid': '289', 'worktype': 'print'}],
#  'imagecount': 1,
#  'totalpageviews': 96,
#  'accessionyear': None,
#  'standardreferencenumber': None,
#  'signed': 'Ichiyūsai Kuniyoshi ga',
#  'classification': 'Prints',
#  'relatedcount': 1,
#  'verificationlevel': 2,
#  'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV017540_dynmc',
#  'titlescount': 1,
#  'peoplecount': 1,
#  'style': None,
#  'lastupdate': '2022-11-30T05:36:11-0500',
#  'commentary': None,
#  'periodid': 248,
#  'technique': None,
#  'edition': None,
#  'description': 'Center sheet of triptych: 1.1988.1 (right), 1.1988.2 (center), 1.1988.3 (left)',
#  'medium': 'Woodblock print (nishiki-e); ink and color on paper',
#  'lendingpermissionlevel': 0,
#  'title': 'Sumida River Crossing (Sumidagawa watashiba no zu)',
#  'accessionmethod': None,
#  'colors': [{'color': '#e1c8af',
#    'spectrum': '#e9715f',
#    'hue': 'Orange',
#    'percent': 0.23942307692307693,
#    'css3': '#f5deb3'},
#   {'color': '#4b7d96',
#    'spectrum': '#536fb5',
#    'hue': 'Blue',
#    'percent': 0.23397435897435898,
#    'css3': '#4682b4'},
#   {'color': '#323232',
#    'spectrum': '#2eb45d',
#    'hue': 'Grey',
#    'percent': 0.2219871794871795,
#    'css3': '#2f4f4f'},
#   {'color': '#e1964b',
#    'spectrum': '#f58843',
#    'hue': 'Yellow',
#    'percent': 0.11467948717948719,
#    'css3': '#cd853f'},
#   {'color': '#c87d4b',
#    'spectrum': '#ed7758',
#    'hue': 'Brown',
#    'percent': 0.05525641025641025,
#    'css3': '#cd853f'},
#   {'color': '#e1af96',
#    'spectrum': '#e9715f',
#    'hue': 'Orange',
#    'percent': 0.028012820512820513,
#    'css3': '#deb887'},
#   {'color': '#7d6464',
#    'spectrum': '#8e5ea7',
#    'hue': 'Brown',
#    'percent': 0.023525641025641024,
#    'css3': '#696969'},
#   {'color': '#967d7d',
#    'spectrum': '#955ba5',
#    'hue': 'Brown',
#    'percent': 0.02141025641025641,
#    'css3': '#808080'},
#   {'color': '#af9696',
#    'spectrum': '#ae5596',
#    'hue': 'Brown',
#    'percent': 0.01467948717948718,
#    'css3': '#bc8f8f'},
#   {'color': '#96644b',
#    'spectrum': '#c25687',
#    'hue': 'Brown',
#    'percent': 0.013397435897435897,
#    'css3': '#a0522d'}],
#  'provenance': None,
#  'groupcount': 0,
#  'dated': 'Late Edo period, circa 1847-1852',
#  'department': 'Department of Asian Art',
#  'dateend': 1852,
#  'people': [{'role': 'Artist',
#    'birthplace': None,
#    'gender': 'male',
#    'displaydate': '1798 - 1861',
#    'prefix': None,
#    'culture': 'Japanese',
#    'displayname': 'Utagawa Kuniyoshi 歌川国芳',
#    'alphasort': 'Utagawa, Kuniyoshi',
#    'name': 'Utagawa Kuniyoshi 歌川国芳',
#    'personid': 27019,
#    'deathplace': None,
#    'displayorder': 1}],
#  'url': 'https://www.harvardartmuseums.org/collections/object/211700',
#  'dateoffirstpageview': '2010-02-13',
#  'century': '19th century',
#  'objectnumber': '1.1988.2',
#  'labeltext': None,
#  'datebegin': 1847,
#  'culture': 'Japanese',
#  'exhibitioncount': 0,
#  'imagepermissionlevel': 0,
#  'mediacount': 0,
#  'objectid': 211700,
#  'techniqueid': None,
#  'dimensions': 'H. 36.6 x W. 24.7 cm (14 7/16 x 9 3/4 in.) (paper)',
#  'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/211700',
#    'type': 'IIIF Manifest',
#    'format': 'application/json',
#    'profile': 'http://iiif.io/api/presentation/2/context.json'}],
#  'dimheight': 36.6,
#  'dimwidth': 24.7}

# %%
from collections import Counter
Counter([item["primaryimageurl"] for item in dataset2 if "primaryimageurl" in item]).most_common(10)
# Out:
# [('https://nrs.harvard.edu/urn-3:HUAM:INV141481_dynmc', 22),
#  ('https://nrs.harvard.edu/urn-3:HUAM:VRS35829_dynmc', 20),
#  ('https://nrs.harvard.edu/urn-3:HUAM:767370', 18),
#  ('https://nrs.harvard.edu/urn-3:HUAM:VRS33642_dynmc', 12),
#  ('https://nrs.harvard.edu/urn-3:HUAM:VRS31249_dynmc', 12),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV203770_dynmc', 10),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV203772_dynmc', 10),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV181639_dynmc', 9),
#  ('https://nrs.harvard.edu/urn-3:HUAM:777226', 7),
#  ('https://nrs.harvard.edu/urn-3:HUAM:777231', 7)]

# %%
Counter([item["techniqueid"] for item in dataset2]).most_common(10)
# Out:
# [(None, 39245),
#  (123, 23067),
#  (107, 16674),
#  (777, 13963),
#  (116, 6467),
#  (220, 3178),
#  (269, 3039),
#  (127, 3005),
#  (136, 2992),
#  (110, 2826)]

# %% [markdown]
# Next, let's deduplicate items that have the same primary gallery image.

# %%
from dataclasses import dataclass
from typing import Optional

@dataclass
class Artwork:
    id: str
    objectnumber: str
    url: str
    image_url: str
    
    dimensions: str
    dimheight: float
    dimwidth: float

    title: Optional[str] # plaintext title
    description: Optional[str] # plaintext description
    labeltext: Optional[str] # optional label text
    people: list # information about artists
    dated: str # "c. 1950" or "1967-68" or "18th century"
    datebegin: int # numerical year or 0
    dateend: int # numerical year or 0
    century: Optional[str] # alternative to "dated" column

    department: str # categorical, about a dozen departments
    division: Optional[str] # modern, european/american, or asian/mediterranean
    culture: Optional[str] # American, Dutch, German, ...
    classification: str # Photographs or Prints or ...
    technique: Optional[str] # Lithograph, Etching, Gelatin silver print, ...
    medium: Optional[str] # Graphite on paper, Oil on canvas, ...

    accessionyear: Optional[int] # when the item was added
    verificationlevel: int # How verified a work is(?)
    totaluniquepageviews: int # a proxy for popularity
    totalpageviews: int # a proxy for popularity

    copyright: Optional[str] # copyright status
    creditline: str # who donated this artwork

dataset3 = []

seen_images = set()

for item in dataset2:
    image_url = item.get("primaryimageurl")
    if image_url is None or image_url in seen_images:
        continue
    seen_images.add(image_url)
    work = Artwork(
        id=item["id"],
        objectnumber=item["objectnumber"],
        url=item["url"],
        image_url=item["primaryimageurl"],
    
        dimensions=item["dimensions"],
        dimheight=item["dimheight"],
        dimwidth=item["dimwidth"],

        title=item.get("title"),
        description=item["description"],
        labeltext=item["labeltext"],
        people=item.get("people", []),
        dated=item["dated"],
        datebegin=max(item["datebegin"], 0),
        dateend=max(item["dateend"], 0),
        century=item["century"],

        department=item["department"],
        division=item["division"],
        culture=item["culture"],
        classification=item["classification"],
        technique=item["technique"],
        medium=item["medium"],

        accessionyear=item["accessionyear"],
        verificationlevel=item["verificationlevel"],
        totaluniquepageviews=item["totaluniquepageviews"],
        totalpageviews=item["totalpageviews"],

        copyright=item["copyright"],
        creditline=item["creditline"],
    )
    dataset3.append(work)

# %%
len(dataset3)
# Out:
# 126499

# %%
dataset3[:10]
# Out:
# [Artwork(id=211700, objectnumber='1.1988.2', url='https://www.harvardartmuseums.org/collections/object/211700', image_url='https://nrs.harvard.edu/urn-3:HUAM:INV017540_dynmc', dimensions='H. 36.6 x W. 24.7 cm (14 7/16 x 9 3/4 in.) (paper)', dimheight=36.6, dimwidth=24.7, title='Sumida River Crossing (Sumidagawa watashiba no zu)', description='Center sheet of triptych: 1.1988.1 (right), 1.1988.2 (center), 1.1988.3 (left)', labeltext=None, people=[{'role': 'Artist', 'birthplace': None, 'gender': 'male', 'displaydate': '1798 - 1861', 'prefix': None, 'culture': 'Japanese', 'displayname': 'Utagawa Kuniyoshi 歌川国芳', 'alphasort': 'Utagawa, Kuniyoshi', 'name': 'Utagawa Kuniyoshi 歌川国芳', 'personid': 27019, 'deathplace': None, 'displayorder': 1}], dated='Late Edo period, circa 1847-1852', datebegin=1847, dateend=1852, century='19th century', department='Department of Asian Art', division='Asian and Mediterranean Art', culture='Japanese', classification='Prints', technique=None, medium='Woodblock print (nishiki-e); ink and color on paper', accessionyear=None, verificationlevel=2, totaluniquepageviews=75, totalpageviews=96, copyright=None, creditline='Harvard Art Museums/Arthur M. Sackler Museum, Anonymous Loan in honor of Israel Goldman'),
#  Artwork(id=211701, objectnumber='1.1988.3', url='https://www.harvardartmuseums.org/collections/object/211701', image_url='https://nrs.harvard.edu/urn-3:HUAM:INV017539_dynmc', dimensions='H. 36.6 x W. 24.5 cm (14 7/16 x 9 5/8 in.) (paper)', dimheight=36.6, dimwidth=24.5, title='Sumida River Crossing (Sumidagawa watashiba no zu)', description='Left sheet of triptych:  1.1988.1 (right), 1.1988.2 (center), 1.1988.3 (left)', labeltext=None, people=[{'role': 'Artist', 'birthplace': None, 'gender': 'male', 'displaydate': '1798 - 1861', 'prefix': None, 'culture': 'Japanese', 'displayname': 'Utagawa Kuniyoshi 歌川国芳', 'alphasort': 'Utagawa, Kuniyoshi', 'name': 'Utagawa Kuniyoshi 歌川国芳', 'personid': 27019, 'deathplace': None, 'displayorder': 1}], dated='Late Edo period, circa 1847-1852', datebegin=1847, dateend=1852, century='19th century', department='Department of Asian Art', division='Asian and Mediterranean Art', culture='Japanese', classification='Prints', technique=None, medium='Woodblock print (nishiki-e); ink and color on paper', accessionyear=None, verificationlevel=2, totaluniquepageviews=70, totalpageviews=89, copyright=None, creditline='Harvard Art Museums/Arthur M. Sackler Museum, Anonymous Loan in honor of Israel Goldman'),
#  Artwork(id=237744, objectnumber='1.1990', url='https://www.harvardartmuseums.org/collections/object/237744', image_url='https://nrs.harvard.edu/urn-3:HUAM:INV191369_dynmc', dimensions='11.8 x 27 cm (4 5/8 x 10 5/8 in.)', dimheight=11.8, dimwidth=27.0, title='A Likely Place for a Salmon', description=None, labeltext=None, people=[{'role': 'Artist', 'birthplace': None, 'gender': 'male', 'displaydate': '1818 - 1910', 'prefix': None, 'culture': 'British, English', 'displayname': 'Francis Seymour Haden', 'alphasort': 'Haden, Francis Seymour', 'name': 'Francis Seymour Haden', 'personid': 24205, 'deathplace': None, 'displayorder': 1}], dated='1869', datebegin=1869, dateend=1869, century='19th century', department='Department of Prints', division='European and American Art', culture='British', classification='Prints', technique='Etching and drypoint', medium=None, accessionyear=None, verificationlevel=3, totaluniquepageviews=32, totalpageviews=44, copyright=None, creditline='Harvard Art Museums/Fogg Museum, Anonymous Loan'),
#  Artwork(id=326451, objectnumber='1.2008', url='https://www.harvardartmuseums.org/collections/object/326451', image_url='https://nrs.harvard.edu/urn-3:HUAM:INV196625_dynmc', dimensions='sheet: 26.3 x 20.4 cm (10 3/8 x 8 1/16 in.)', dimheight=26.3, dimwidth=20.4, title='Saturn, Seated with three Putti Holding a Painting', description=None, labeltext=None, people=[{'role': 'Artist', 'birthplace': None, 'gender': 'male', 'displaydate': '1606 - 1680', 'prefix': None, 'culture': 'Italian', 'displayname': 'Giovanni Francesco Grimaldi', 'alphasort': 'Grimaldi, Giovanni Francesco', 'name': 'Giovanni Francesco Grimaldi', 'personid': 23592, 'deathplace': None, 'displayorder': 1}, {'role': 'Previous attribution', 'birthplace': None, 'gender': 'unknown', 'displaydate': '1611 - 1669', 'prefix': 'Previously attributed to', 'culture': None, 'displayname': 'Previously attributed to Francesco Giovane', 'alphasort': 'Giovane, Francesco', 'name': 'Francesco Giovane', 'personid': 53622, 'deathplace': None, 'displayorder': 2}], dated='17th century', datebegin=0, dateend=0, century='17th century', department='Department of Prints', division='European and American Art', culture='Italian', classification='Prints', technique='Etching', medium='Etching with polishing scratches and platetone', accessionyear=None, verificationlevel=3, totaluniquepageviews=124, totalpageviews=172, copyright=None, creditline='Harvard Art Museums/Fogg Museum, Anonymous Loan'),
#  Artwork(id=175117, objectnumber='1.2013', url='https://www.harvardartmuseums.org/collections/object/175117', image_url='https://nrs.harvard.edu/urn-3:HUAM:DDC232154_dynmc', dimensions='96.5 x 72.4 cm (38 x 28 1/2 in.)\r\nframed: 125.1 x 100.6 cm (49 1/4 x 39 5/8 in.)', dimheight=96.5, dimwidth=72.4, title='Mary Elizabeth Robbins', description=None, labeltext='William Morris Hunt, who spent three years as a student at Harvard, was the preeminent portraitist in mid-nineteenth-century Boston. With its soft focus, warm golden tonalities, and partially turned figure, this work reflects the influence of the famed French painter Jean-François Millet, with whom Hunt trained in the 1850s. As Boston’s leading artist, Hunt wielded tremendous influence, and he used his writings, teachings, and extensive social connections to introduce the city’s artists and art patrons to the work of Millet and other members of the Barbizon school.\r\nThe sitter, Mary Elizabeth Robbins, was married to Boston entrepreneur and industrialist Royal Robbins, founder of the Boston Watch Company. Robbins made his fortune manufacturing affordable and accurate timepieces for the Union Army during the Civil War. This portrait was probably displayed in the fashionable Back Bay home that the couple had built in 1864.', people=[{'role': 'Artist', 'birthplace': 'Brattleboro, VT', 'gender': 'male', 'displaydate': '1824 - 1879', 'prefix': None, 'culture': 'American', 'displayname': 'William Morris Hunt', 'alphasort': 'Hunt, William Morris', 'name': 'William Morris Hunt', 'personid': 26664, 'deathplace': 'Isles of Shoals, NH', 'displayorder': 1}], dated='1866', datebegin=1866, dateend=1866, century='19th century', department='Department of American Paintings, Sculpture & Decorative Arts', division='European and American Art', culture='American', classification='Paintings', technique=None, medium='Oil on canvas', accessionyear=None, verificationlevel=3, totaluniquepageviews=720, totalpageviews=803, copyright=None, creditline='Harvard Art Museums/Fogg Museum, Loan from Amelia Choate Reilly'),
#  Artwork(id=184113, objectnumber='1.2018.1', url='https://www.harvardartmuseums.org/collections/object/184113', image_url='https://nrs.harvard.edu/urn-3:HUAM:770474', dimensions='27.2 x 11.1 cm (10 11/16 x 4 3/8 in.)', dimheight=27.2, dimwidth=11.1, title='Standing Boy seen from Behind', description=None, labeltext=None, people=[{'role': 'Artist', 'birthplace': 'Dieppe', 'gender': 'unknown', 'displaydate': 'c. 1610 - 1652', 'prefix': None, 'culture': 'Dutch', 'displayname': 'Jan Asselijn', 'alphasort': 'Asselijn, Jan', 'name': 'Jan Asselijn', 'personid': 33946, 'deathplace': 'Amsterdam', 'displayorder': 1}], dated='17th century', datebegin=0, dateend=0, century='17th century', department='Department of Drawings', division='European and American Art', culture='Dutch', classification='Drawings', technique=None, medium='Black and white chalk on blue antique laid paper; framing line in dark brown ink', accessionyear=2018, verificationlevel=0, totaluniquepageviews=89, totalpageviews=100, copyright=None, creditline='The Maida and George Abrams Collection, Fogg Art Museum, Harvard University, Cambridge, Massachusetts, Promised Gift'),
#  Artwork(id=183480, objectnumber='1.2018.2', url='https://www.harvardartmuseums.org/collections/object/183480', image_url='https://nrs.harvard.edu/urn-3:HUAM:51959_dynmc', dimensions='12 x 19.7 cm (4 3/4 x 7 3/4 in.)', dimheight=12.0, dimwidth=19.7, title='Feathered Cone Shell', description=None, labeltext=None, people=[{'role': 'Artist', 'birthplace': 'Middelburg, Netherlands', 'gender': 'unknown', 'displaydate': '1593 - 1657', 'prefix': None, 'culture': 'Dutch', 'displayname': 'Balthasar van der Ast', 'alphasort': 'Ast, Balthasar van der', 'name': 'Balthasar van der Ast', 'personid': 21745, 'deathplace': 'Delft, Netherlands', 'displayorder': 1}, {'role': 'Previous attribution', 'birthplace': 'Dordrecht, Netherlands', 'gender': 'unknown', 'displaydate': '1607 - after 1667', 'prefix': 'Previously attributed to', 'culture': 'Dutch', 'displayname': 'Previously attributed to Bartholomeus Abrahamsz. Assteyn', 'alphasort': 'Assteyn, Bartholomeus Abrahamsz.', 'name': 'Bartholomeus Abrahamsz. Assteyn', 'personid': 19970, 'deathplace': 'Dordrecht, Netherlands', 'displayorder': 2}], dated='c. 1620-40', datebegin=1615, dateend=1645, century='17th century', department='Department of Drawings', division='European and American Art', culture='Dutch', classification='Drawings', technique=None, medium='Brown ink, transparent and opaque watercolor, and white opaque watercolor on off-white antique laid paper, mounted; framing line in brown ink', accessionyear=2018, verificationlevel=3, totaluniquepageviews=163, totalpageviews=185, copyright=None, creditline='The Maida and George Abrams Collection, Fogg Art Museum, Harvard University, Cambridge, Massachusetts, Promised Gift'),
#  Artwork(id=76986, objectnumber='1.2018.4', url='https://www.harvardartmuseums.org/collections/object/76986', image_url='https://nrs.harvard.edu/urn-3:HUAM:770066', dimensions='6.3 x 9.1 cm (2 1/2 x 3 9/16 in.)', dimheight=6.3, dimwidth=9.1, title='Small Sketch of Four Figures: Two Men Skating; Two Women Bending at Work; verso: Profile portrait bust of a boy with a wide-brimmed hat facing left', description=None, labeltext=None, people=[{'role': 'Artist', 'birthplace': 'Amsterdam, Netherlands', 'gender': 'unknown', 'displaydate': '1585 - 1634', 'prefix': None, 'culture': 'Dutch', 'displayname': 'Hendrick Barentsz. Avercamp', 'alphasort': 'Avercamp, Hendrick Barentsz.', 'name': 'Hendrick Barentsz. Avercamp', 'personid': 19303, 'deathplace': 'Kampen, Netherlands', 'displayorder': 1}], dated='17th century', datebegin=0, dateend=0, century='17th century', department='Department of Drawings', division='European and American Art', culture='Dutch', classification='Drawings', technique=None, medium='Brown ink and transparent watercolor over graphite on off-white antique laid paper, partial framing line in graphite; verso: graphite on off-white antique laid paper', accessionyear=2018, verificationlevel=3, totaluniquepageviews=43, totalpageviews=45, copyright=None, creditline='The Maida and George Abrams Collection, Fogg Art Museum, Harvard University, Cambridge, Massachusetts, Promised Gift'),
#  Artwork(id=183479, objectnumber='1.2018.8', url='https://www.harvardartmuseums.org/collections/object/183479', image_url='https://nrs.harvard.edu/urn-3:HUAM:21193_dynmc', dimensions='17.1 x 24.6 cm (6 3/4 x 9 11/16 in.)', dimheight=17.1, dimwidth=24.6, title='River Landscape with a Church', description=None, labeltext=None, people=[{'role': 'Artist', 'birthplace': 'Rotterdam', 'gender': 'unknown', 'displaydate': '1636 - 1684', 'prefix': None, 'culture': 'Dutch', 'displayname': 'Gerrit Battem', 'alphasort': 'Battem, Gerrit', 'name': 'Gerrit Battem', 'personid': 19313, 'deathplace': 'Rotterdam', 'displayorder': 1}], dated='17th century', datebegin=0, dateend=0, century='17th century', department='Department of Drawings', division='European and American Art', culture='Dutch', classification='Drawings', technique=None, medium='Opaque and transparent watercolor on off-white antique laid paper, partial framing line in black ink', accessionyear=2018, verificationlevel=3, totaluniquepageviews=74, totalpageviews=89, copyright=None, creditline='The Maida and George Abrams Collection, Fogg Art Museum, Harvard University, Cambridge, Massachusetts, Promised Gift'),
#  Artwork(id=191157, objectnumber='1.2018.9', url='https://www.harvardartmuseums.org/collections/object/191157', image_url='https://nrs.harvard.edu/urn-3:HUAM:71829_dynmc', dimensions='18.5 x 22.4 cm (7 5/16 x 8 13/16 in.)', dimheight=18.5, dimwidth=22.4, title='Man and Woman Conversing at the Door--An Interior; verso: Sketch', description=None, labeltext=None, people=[{'role': 'Artist', 'birthplace': 'Haarlem, Netherlands', 'gender': 'male', 'displaydate': '1631/32 - 1664', 'prefix': None, 'culture': 'Dutch', 'displayname': 'Cornelis Bega', 'alphasort': 'Bega, Cornelis', 'name': 'Cornelis Bega', 'personid': 27256, 'deathplace': 'Haarlem, Netherlands', 'displayorder': 1}], dated='17th century', datebegin=0, dateend=0, century='17th century', department='Department of Drawings', division='European and American Art', culture='Dutch', classification='Drawings', technique=None, medium='Black chalk and gray wash on off-white antique laid paper, framing line in brown ink; verso: black chalk', accessionyear=2018, verificationlevel=3, totaluniquepageviews=18, totalpageviews=21, copyright=None, creditline='The Maida and George Abrams Collection, Fogg Art Museum, Harvard University, Cambridge, Massachusetts, Promised Gift')]

# %%
import pandas as pd
from inline_sql import sql, sql_val

df = pd.DataFrame(dataset3)

# %%
df.columns
# Out:
# Index(['id', 'objectnumber', 'url', 'image_url', 'dimensions', 'dimheight',
#        'dimwidth', 'title', 'description', 'labeltext', 'people', 'dated',
#        'datebegin', 'dateend', 'century', 'department', 'division', 'culture',
#        'classification', 'technique', 'medium', 'accessionyear',
#        'verificationlevel', 'totaluniquepageviews', 'totalpageviews',
#        'copyright', 'creditline'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
sns.scatterplot(x="datebegin", y="dateend",
                data=sql^ "SELECT datebegin, dateend FROM df WHERE LEAST(datebegin, dateend) > 0")
# Out:
# <AxesSubplot: xlabel='datebegin', ylabel='dateend'>

# %%
sns.scatterplot(x="dimwidth", y="dimheight", data=df)
# Out:
# <AxesSubplot: xlabel='dimwidth', ylabel='dimheight'>

# %%
sql^ "SELECT * FROM df WHERE dimwidth > 5000"
# Out:
#        id objectnumber                                                url  \
# 0  192423     1985.569  https://www.harvardartmuseums.org/collections/...
# 1  192399     1985.570  https://www.harvardartmuseums.org/collections/...
# 2  192395     1985.702  https://www.harvardartmuseums.org/collections/...
# 3  192477     1985.721  https://www.harvardartmuseums.org/collections/...
# 4  260628       M21485  https://www.harvardartmuseums.org/collections/...
#
#                                            image_url  \
# 0  https://nrs.harvard.edu/urn-3:HUAM:INV019522_d...
# 1  https://nrs.harvard.edu/urn-3:HUAM:INV006416_d...
# 2  https://nrs.harvard.edu/urn-3:HUAM:INV007068_d...
# 3  https://nrs.harvard.edu/urn-3:HUAM:INV006671_d...
# 4  https://nrs.harvard.edu/urn-3:HUAM:INV166184_d...
#
#                                     dimensions  dimheight  dimwidth  \
# 0     33.6 x 5251.8 cm (13 1/4 x 2067 5/8 in.)      33.60    5251.8
# 1  32.8 x 6073.9 cm (12 15/16 x 2391 5/16 in.)      32.80    6073.9
# 2         34.3 x 7757.2 cm (13 1/2 x 3054 in.)      34.30    7757.2
# 3     42.5 x 6483.1 cm (16 3/4 x 2552 3/8 in.)      42.50    6483.1
# 4      0.08 x 33038 cm (1/16 x 13007 1/16 in.)       0.08   33038.0
#
#                                                title description labeltext  \
# 0  Illustrated Scroll of the Deity of Kifune Shri...         NaN       NaN
# 1  Annual Events in the Form of a Poetry Contest ...         NaN       NaN
# 2  Illustrated Story of the Priest Saigyō (Saigyō...         NaN       NaN
# 3  Illustrated Scroll of Birds (Chōrui zukan) in ...         NaN       NaN
# 4                                          Canto XII         NaN       NaN
#
#    ...   culture classification   technique  \
# 0  ...  Japanese      Paintings         NaN
# 1  ...  Japanese      Paintings         NaN
# 2  ...  Japanese      Paintings         NaN
# 3  ...  Japanese      Paintings         NaN
# 4  ...  American         Prints  Lithograph
#
#                                               medium accessionyear  \
# 0  Set of three large handscrolls; ink, color, go...        1985.0
# 1  Handscrolls: five; ink, color, gold and silver...        1985.0
# 2  4 handscrolls; ink and light color on paper wi...        1985.0
# 3           Handscrolls: two; ink and color on paper        1985.0
# 4                                                NaN        1990.0
#
#   verificationlevel totaluniquepageviews totalpageviews  \
# 0                 0                   38             48
# 1                 0                    4              6
# 2                 0                   97            126
# 3                 0                   25             28
# 4                 2                    3              3
#
#                                            copyright  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  © The Barnett Newman Foundation, New York / Ar...
#
#                                           creditline
# 0  Harvard Art Museums/Arthur M. Sackler Museum, ...
# 1  Harvard Art Museums/Arthur M. Sackler Museum, ...
# 2  Harvard Art Museums/Arthur M. Sackler Museum, ...
# 3  Harvard Art Museums/Arthur M. Sackler Museum, ...
# 4  Harvard Art Museums/Fogg Museum, Gift of Annal...
#
# [5 rows x 27 columns]

# %%
sql^ "SELECT AVG(dimwidth), AVG(dimheight) FROM df"
# Out:
#    avg(dimwidth)  avg(dimheight)
# 0      24.470711       22.206538

# %%
[
    sql_val^ "SELECT COUNT() FROM df WHERE dimheight > 200",
    sql_val^ "SELECT COUNT() FROM df WHERE dimwidth > 250",
]
# Out:
# [328, 270]

# %%
[
    sql_val^ "SELECT COUNT() FROM df WHERE dimheight < 1",
    sql_val^ "SELECT COUNT() FROM df WHERE dimwidth < 1",
]
# Out:
# [145, 190]

# %%
sns.displot(sql^ "SELECT dateend FROM df WHERE datebegin > 0")

# %%
df.describe()
# Out:
#                   id      dimheight       dimwidth      datebegin  \
# count  126499.000000  126499.000000  126499.000000  126499.000000
# mean   182094.985241      22.206538      24.470711    1587.465925
# std     98950.039327      46.154439     109.629312     715.834921
# min      1412.000000       0.050000       0.060000       0.000000
# 25%    126097.500000       8.500000       9.600000    1839.000000
# 50%    168913.000000      16.100000      17.800000    1930.000000
# 75%    281071.500000      27.900000      27.300000    1946.000000
# max    374745.000000   13589.000000   33038.000000    2015.000000
#
#              dateend  accessionyear  verificationlevel  totaluniquepageviews  \
# count  126499.000000   93611.000000      126499.000000         126499.000000
# mean     1591.627847    1988.722725           2.628060             26.228935
# std       716.875511      28.303498           0.872413            131.328136
# min         0.000000    1765.000000           0.000000              0.000000
# 25%      1849.000000    1967.000000           2.000000              1.000000
# 50%      1931.000000    2003.000000           3.000000              4.000000
# 75%      1955.000000    2011.000000           3.000000             17.000000
# max      2015.000000    2022.000000           4.000000          12016.000000
#
#        totalpageviews
# count   126499.000000
# mean        32.233275
# std        159.694357
# min          0.000000
# 25%          1.000000
# 50%          5.000000
# 75%         21.000000
# max      13593.000000

# %%
sns.barplot(x="verificationlevel", y="count", hue="division",
            data=sql^ "SELECT verificationlevel, division, COUNT() AS count FROM df GROUP BY 1, 2")
# Out:
# <AxesSubplot: xlabel='verificationlevel', ylabel='count'>

# %%
dataset4 = [Artwork(*row) for _, row in (sql^ """
    SELECT * FROM df
    WHERE dimheight >= 1 AND dimheight <= 200
    AND dimwidth >= 1 AND dimwidth <= 250
""").iterrows()]

# %%
len(dataset4)
# Out:
# 125694

# %%
df4 = pd.DataFrame(dataset4)

# %%
sns.jointplot(x="dimwidth", y="dimheight", marker="+", data=df4)

# %%
sns.jointplot(x="dimwidth", y="dimheight", hue="division", marker="+", data=df4)
# Out:
# d:\Developer_Zaid\disart\backend\env\lib\site-packages\IPython\core\events.py:89: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)

# %%
df4.medium.value_counts()[:15]
# Out:
# Graphite on paper                           2863
# Oil on canvas                               1872
# Graphite on off-white wove paper            1429
# Black crayon on paper                       1021
# Gelatin silver print on card                 870
# Ink, opaque watercolor and gold on paper     728
# Gelatin silver print                         632
# Terracotta                                   576
# Bronze                                       535
# Black ink on tan wove paper                  419
# Plaster                                      414
# Black ink on off-white wove paper            378
# Ink on paper                                 369
# Woodblock print; ink and color on paper      344
# Silver                                       339
# Name: medium, dtype: int64

# %%
df4.technique.value_counts()[:15]
# Out:
# Gelatin silver print                    21456
# Negative, gelatin silver (film)         16261
# Negative, gelatin silver (35mm film)    13672
# Etching                                  5397
# Slide, 35 mm, black and white            3158
# Photomechanical print                    2953
# Slide, 35 mm, color                      2946
# Lithograph                               2538
# Engraving                                2291
# Albumen silver print                     2145
# Negative, gelatin dry plate (glass)      1934
# Photolithograph                           925
# Screen print                              914
# Woodcut                                   848
# Cast, lost-wax process                    669
# Name: technique, dtype: int64

# %%
(sql^ "SELECT * FROM df4 WHERE medium = 'Graphite on paper'").technique.value_counts()
# Out:
# Photomechanical print    1
# Name: technique, dtype: int64

# %%
(sql^ "SELECT * FROM df4 WHERE medium = 'Oil on canvas'").technique.value_counts()
# Out:
# Grisaille    3
# Collage      1
# Name: technique, dtype: int64

# %%
sns.jointplot(x="dimwidth", y="dimheight", hue="division", marker="+",
              data=sql^ "SELECT * FROM df4 WHERE medium = 'Oil on canvas'")

# %%
sql_val^ "SELECT url FROM df4 WHERE medium = 'Oil on canvas' LIMIT 1"
# Out:
# 'https://www.harvardartmuseums.org/collections/object/175117'

# %%
sql_val^ "SELECT url FROM df4 WHERE technique = 'Gelatin silver print' LIMIT 1 OFFSET 100"
# Out:
# 'https://www.harvardartmuseums.org/collections/object/159178'

# %%
sql_val^ "SELECT url FROM df4 WHERE medium = 'Bronze' LIMIT 1"
# Out:
# 'https://www.harvardartmuseums.org/collections/object/226633'

# %%
import numpy as np

sns.catplot(x="totalpageviews", y="department", kind="boxen",
            data=df4.assign(totalpageviews=np.minimum(df4.totalpageviews, 1000)), aspect=2.5) # type: ignore

# %%
sql^ """
    SELECT objectnumber, url, title, totalpageviews FROM df4
    ORDER BY totalpageviews DESC
    LIMIT 10
"""
# Out:
#   objectnumber                                                url  \
# 0  2002.50.150  https://www.harvardartmuseums.org/collections/...
# 1     1943.268  https://www.harvardartmuseums.org/collections/...
# 2     1943.277  https://www.harvardartmuseums.org/collections/...
# 3      1924.27  https://www.harvardartmuseums.org/collections/...
# 4     1943.252  https://www.harvardartmuseums.org/collections/...
# 5     2014.301  https://www.harvardartmuseums.org/collections/...
# 6      1937.78  https://www.harvardartmuseums.org/collections/...
# 7     1930.191  https://www.harvardartmuseums.org/collections/...
# 8        P12.C  https://www.harvardartmuseums.org/collections/...
# 9      86.1995  https://www.harvardartmuseums.org/collections/...
#
#                                                title  totalpageviews
# 0  Court of Gayumars (painting, recto; text, vers...           13593
# 1                                     The Apparition           11176
# 2                                     Spring Bouquet           11142
# 3                                 Mystic Crucifixion            9710
# 4                          Raphael and the Fornarina            8060
# 5                                  Grazing Horses IV            7911
# 6                             Summer Scene (Bathers)            7707
# 7                             Portrait of an Old Man            7589
# 8   Head of One of Laocoön's Sons, after the Antique            7483
# 9  Untitled (You construct intricate rituals whic...            6804

# %%
sql^ """
    SELECT objectnumber, url, title, totalpageviews FROM df4
    WHERE department LIKE '%Clock Collection'
    ORDER BY totalpageviews DESC
    LIMIT 10
"""
# Out:
#   objectnumber                                                url  \
# 0      HUCL.20  https://www.harvardartmuseums.org/collections/...
# 1       HUCL.6  https://www.harvardartmuseums.org/collections/...
# 2      HUCL.46  https://www.harvardartmuseums.org/collections/...
# 3      HUCL.18  https://www.harvardartmuseums.org/collections/...
# 4      HUCL.27  https://www.harvardartmuseums.org/collections/...
# 5      HUCL.28  https://www.harvardartmuseums.org/collections/...
# 6      HUCL.48  https://www.harvardartmuseums.org/collections/...
#
#                             title  totalpageviews
# 0                    Mantel Clock             201
# 1                Banjo Wall Clock             108
# 2           Banjo Regulator Clock              27
# 3                Banjo Wall Clock              24
# 4  Willard-Style Banjo Wall Clock              15
# 5                    Mantel Clock              12
# 6                      Wall Clock               5

# %%
sql^ """
    SELECT objectnumber, url, title, totalpageviews FROM df4
    WHERE department LIKE '%Photographs%' AND totalpageviews <= 50
    ORDER BY totalpageviews DESC
    LIMIT 10
"""
# Out:
#    objectnumber                                                url  \
# 0    P1970.2303  https://www.harvardartmuseums.org/collections/...
# 1    P1970.3166  https://www.harvardartmuseums.org/collections/...
# 2     P1972.239  https://www.harvardartmuseums.org/collections/...
# 3     P1972.104  https://www.harvardartmuseums.org/collections/...
# 4      P1981.24  https://www.harvardartmuseums.org/collections/...
# 5  P1982.359.75  https://www.harvardartmuseums.org/collections/...
# 6      P1991.35  https://www.harvardartmuseums.org/collections/...
# 7    P1992.19.4  https://www.harvardartmuseums.org/collections/...
# 8      P1995.46  https://www.harvardartmuseums.org/collections/...
# 9     P1998.136  https://www.harvardartmuseums.org/collections/...
#
#                                                title  totalpageviews
# 0                               Untitled (Hong Kong)              50
# 1  Untitled (Mulhall family, sharecroppers, Ozark...              50
# 2                      Young Boy, Gondeville, France              50
# 3                              Church Organ, Alabama              50
# 4                          Untitled (hermaphrodites)              50
# 5  Untitled (four photographs, Colonel Bathurst; ...              50
# 6                        114. Girl Dressing Her Hair              50
# 7  The View from the Roof of the Yungang Hotel, D...              50
# 8                               Portait of John Cage              50
# 9            Untitled (Ben Shahn, Jersey Homesteads)              50

# %%
import altair as alt

alt.Chart(
    sql^ """
    SELECT department, century, COUNT() AS count
    FROM df4
    WHERE century IS NOT NULL
    GROUP BY 1, 2
    HAVING count > 100
    """
).mark_bar().encode(
    x="count:Q",
    y="department:N",
    color="century:N",
)
# Out:
# alt.Chart(...)

# %%
import altair as alt

alt.Chart(
    sql^ """
    SELECT department, century, COUNT() AS count
    FROM df4
    WHERE century IS NOT NULL AND totalpageviews >= 100
    GROUP BY 1, 2
    HAVING count >= 5
    """
).mark_bar().encode(
    x="count:Q",
    y="department:N",
    color="century:N",
    tooltip=["century", "count"],
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(
    sql^ """
    SELECT department, medium, COUNT() AS count
    FROM df4
    WHERE medium IS NOT NULL AND totalpageviews >= 50
    GROUP BY 1, 2
    HAVING count > 25
    """ # type: ignore
).mark_bar().encode(
    x="count:Q",
    y="department:N",
    color="medium:N",
    tooltip=["medium", "count"],
).properties(
    title="Artwork with at least 30 page views by medium and department",
)
# Out:
# alt.Chart(...)

# %%
import altair as alt

alt.Chart(
    sql^ """
    SELECT department, technique, COUNT() AS count
    FROM df4
    WHERE technique IS NOT NULL AND totalpageviews >= 30
    GROUP BY 1, 2
    HAVING count > 25
    """  # type: ignore
).mark_bar().encode(
    x="count:Q",
    y="department:N",
    color="technique:N",
    tooltip=["technique", "count"],
)
# Out:
# alt.Chart(...)

# %%
len(df4)
# Out:
# 125694

# %%
sql_val^ "SELECT COUNT() FROM df4 WHERE totalpageviews >= 30"
# Out:
# 24533

# %%
df.people.map(len).value_counts()
# Out:
# 1     109856
# 2       7437
# 0       7414
# 3       1569
# 4        205
# 5          9
# 8          2
# 6          2
# 7          2
# 10         1
# 9          1
# 15         1
# Name: people, dtype: int64

# %%
sql_val^ "SELECT people FROM df WHERE LEN(people) >= 3 LIMIT 1"
# Out:
# [{'role': 'Artist',
#   'birthplace': 'Dordrecht',
#   'gender': 'unknown',
#   'displaydate': '1650 - after 1707',
#   'prefix': None,
#   'culture': 'Dutch',
#   'displayname': 'Justus de Gelder',
#   'alphasort': 'Gelder, Justus de',
#   'name': 'Justus de Gelder',
#   'personid': 56344,
#   'deathplace': 'Vianen (or Amsterdam?)',
#   'displayorder': 1},
#  {'role': 'Previous attribution',
#   'birthplace': 'Leiden',
#   'gender': 'male',
#   'displaydate': '1606 - 1669',
#   'prefix': 'Previously attributed to',
#   'culture': 'Dutch',
#   'displayname': 'Previously attributed to Rembrandt Harmensz. van Rijn',
#   'alphasort': 'Rembrandt Harmensz. van Rijn',
#   'name': 'Rembrandt Harmensz. van Rijn',
#   'personid': 28241,
#   'deathplace': 'Amsterdam',
#   'displayorder': 2},
#  {'role': 'Previous attribution',
#   'birthplace': 'Dordrecht',
#   'gender': 'male',
#   'displaydate': '1634 - 1693',
#   'prefix': 'Previously attributed to',
#   'culture': 'Dutch',
#   'displayname': 'Previously attributed to Nicolaes Maes',
#   'alphasort': 'Maes, Nicolaes',
#   'name': 'Nicolaes Maes',
#   'personid': 27324,
#   'deathplace': 'Amsterdam',
#   'displayorder': 3}]

# %% [markdown]
# Our final, last two transformations will be to filter by `totalpageviews >= 30` then finally, to transform the `people` column into a simple flat list of ordinary string names.

# %%
dataset5 = []

for item in dataset4:
    if item.totalpageviews >= 30:
        # Fix None turning into float NaNs due to pandas
        new_item = Artwork(**{
            k: None if isinstance(v, float) and np.isnan(v) else v for k, v in item.__dict__.items()
        })  # type: ignore
        new_item.people = [person["name"] for person in new_item.people]
        dataset5.append(new_item)

len(dataset5)
# Out:
# 24533

# %%
with open("../data/artmuseums-clean.json", "w") as f:
    json.dump([x.__dict__ for x in dataset5], f)
